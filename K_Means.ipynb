# %% [markdown]
# <a href="https://colab.research.google.com/github/Sakshamsinha23/Machine-Learning/blob/main/K_Means.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pyforest
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pyforest: filename=pyforest-1.1.2-py2.py3-none-any.whl size=15897 sha256=e8dd11384a7762ea8f335ccaba4eb995d91e113a368a14afcba45ad3112b4d81
#   Stored in directory: /root/.cache/pip/wheels/c5/ca/73/5cdc3d087111bfbdef90be5457aa03c00c0e32241b2752445c
# Successfully built pyforest
# ...

# %%
import pyforest

# %%
data=pd.read_csv('/content/IRIS.csv')
data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
data.drop(columns='species',inplace=True)

# %%
data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
sns.pairplot(data=data)
plt.show()

# %%
#WCSS

from sklearn.cluster import KMeans

# %%
wcss=[]

for i in range(2,21):
    km=KMeans(n_clusters=i,init='k-means++')
    km.fit(data)
    wcss.append(km.inertia_)

# %%
plt.figure(figsize=(10,5))

plt.plot([i for  i in range(2,21)],wcss,marker='o')
plt.xlabel('Number of clusters')
plt.xticks([i for  i in range(2,21)])
plt.ylabel('WCSS')
plt.grid()
plt.show()

# %%
kmn=KMeans(n_clusters=3)
data['PREDICT']=kmn.fit_predict(data)

# %%
sns.pairplot(data=data,hue='PREDICT')
