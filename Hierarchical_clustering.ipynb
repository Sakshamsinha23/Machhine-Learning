# %% [markdown]
# <a href="https://colab.research.google.com/github/Sakshamsinha23/Machine-Learning/blob/main/Hierarchical_clustering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pyforest
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pyforest: filename=pyforest-1.1.2-py2.py3-none-any.whl size=15897 sha256=07abba3078dce590395be9263d19ce5e2962c6311edcf7b860f1512a5e30357f
#   Stored in directory: /root/.cache/pip/wheels/c5/ca/73/5cdc3d087111bfbdef90be5457aa03c00c0e32241b2752445c
# Successfully built pyforest
# ...

# %%
import pyforest

# %%
data=pd.read_csv('/content/iris_data.csv')
data
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
data.drop(columns=['Id','Species'],inplace=True)
data.head()

# %%
sns.pairplot(data=data)
plt.show()

# %%
import scipy.cluster.hierarchy as sc

plt.figure(figsize=(17,17))
sc.dendrogram(sc.linkage(data,method='single',metric='euclidean'))
plt.show()

# %%
from sklearn.cluster import AgglomerativeClustering

# %%
ac=AgglomerativeClustering(n_clusters=2,linkage='single')
data['PREDICT']=ac.fit_predict(data)

# %%
data.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  PREDICT
# 0            5.1           3.5            1.4           0.2        1
# 1            4.9           3.0            1.4           0.2        1
# 2            4.7           3.2            1.3           0.2        1
# 3            4.6           3.1            1.5           0.2        1
# 4            5.0           3.6            1.4           0.2        1

# %%
sns.pairplot(data=data,hue='PREDICT')
plt.show()
